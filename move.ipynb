# %%
import os

#put a text doc with the list of tcp ids from the time range you are interested in
#make sure to upload it to jupyter notebook or the dcc and input the correct pathway
with open(r"1606-1612ids.txt", 'r', encoding='utf-8') as ids:
    relevantIDs = []
    data = ids.readlines()
    for id in data:
        relevantIDs.append(id.strip() + ".txt")
  

    for file in os.scandir("/hpc/group/datap2023ecbc/lemmatized_without_stop"):
        name = os.path.basename(file)
        if name in relevantIDs:
            with open(file, encoding="utf-8") as EPextracted:
                #remember to put the correct pathway for output and input! based off of what you are trying
                #to understand!
                with open(os.path.join(r"/hpc/group/datap2023ecbc/1606-1612_texts", name), 'w+') as lowerFile:
                    data = EPextracted.read()
                    lowerFile.write(data.lower())
                    print(name)
# Out:
# A02058.txt
# A11512.txt
# A04099.txt
# A20964.txt
# A69093.txt
# A68730.txt
# A20519.txt
# A23100.txt
# A08219.txt
# A21439.txt
# A12970.txt
# B00422.txt
# A20683.txt
# A10050.txt
# A12738.txt
# A01471.txt
# A10804.txt
# A03019.txt
# A72233.txt
# A20954.txt
# A00430.txt
# A02685.txt
# A10835.txt
# A68832.txt
# A04286.txt
# A12091.txt
# A20115.txt
# A20540.txt
# A03022.txt
# A17985.txt
# A03653.txt
# A03221.txt
# A19264.txt
# A04127.txt
# B12780.txt
# A01675.txt
# A68281.txt
# B15540.txt
# A01565.txt
# A02183.txt
# A03400.txt
# A11154.txt
# A06458.txt
# A05387.txt
# A72806.txt
# A20158.txt
# A19841.txt
# A00725.txt
# A08130.txt
# A11686.txt
# A13274.txt
# A04852.txt
# A03002.txt
# A02733.txt
# A12654.txt
# A14516.txt
# A03713.txt
# A07266.txt
# A04843.txt
# A01148.txt
# A18403.txt
# A02567.txt
# A20588.txt
# A06931.txt
# A06138.txt
# A20095.txt
# A18208.txt
# A18501.txt
# A06705.txt
# A73588.txt
# A07446.txt
# A11347.txt
# A11870.txt
# A04643.txt
# A11600.txt
# A16995.txt
# ...
